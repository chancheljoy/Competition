# %% [markdown]
# # Big Mart Sales Prediction

# %%
#importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#to avoid truncation of columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import warnings
warnings.filterwarnings("ignore")

# %%
#storing the train dataset to a dataframe named 'data'
data=pd.read_csv('train_v9rqX0R.csv')

# %%
#displaying the first few rows
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data.shape
# Out:
# (8523, 12)

# %% [markdown]
# There are 8523 observations and 12 features in the dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
#descriptive statistics
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
#descriptive statistics
data.describe(include=object)
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                5                     16
# top              FDW13          Low Fat  Fruits and Vegetables
# freq                10             5089                   1232
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               8523        6113                 8523               8523
# unique                10           3                    3                  4
# top               OUT027      Medium               Tier 3  Supermarket Type1
# freq                 935        2793                 3350               5577

# %% [markdown]
# # 1. Exploratory Data Analysis

# %% [markdown]
# # 2. Pre-processing

# %% [markdown]
# ## 2.1 Handling null values

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# There are null values in two features.<br>'Item_Weight' and 'Outlet_Size'

# %% [markdown]
# ### 2.1.1 Handling null values in 'Item_Weight'

# %%
#displaying item details
data[['Item_Identifier','Item_Weight']].sort_values(by=['Item_Identifier'])
# Out:
#      Item_Identifier  Item_Weight
# 8043           DRA12       11.600
# 118            DRA12       11.600
# 1693           DRA12       11.600
# 1197           DRA12       11.600
# 1245           DRA12       11.600
# 7467           DRA12       11.600
# 8195           DRA24       19.350
# 6863           DRA24       19.350
# 2879           DRA24          NaN
# 4416           DRA24          NaN
# 4900           DRA24       19.350
# 4130           DRA24       19.350
# 1148           DRA24       19.350
# 3927           DRA59        8.270
# 1876           DRA59        8.270
# 6338           DRA59        8.270
# 3962           DRA59        8.270
# 8371           DRA59        8.270
# 6179           DRA59          NaN
# 6057           DRA59          NaN
# 5609           DRA59        8.270
# 3465           DRB01        7.390
# 3733           DRB01          NaN
# 3571           DRB01        7.390
# 1836           DRB13        6.115
# 2479           DRB13        6.115
# 6626           DRB13        6.115
# 4135           DRB13        6.115
# 1431           DRB13        6.115
# 7811           DRB24        8.785
# 7619           DRB24        8.785
# 6128           DRB24        8.785
# 2657           DRB24        8.785
# 2533           DRB25          NaN
# 8063           DRB25       12.300
# 776            DRB25       12.300
# 6058           DRB25       12.300
# 8289           DRB25       12.300
# 3161           DRB25       12.300
# 1918           DRB48       16.750
# 5627           DRB48       16.750
# 8106           DRB48       16.750
# 458            DRB48          NaN
# 2944           DRB48       16.750
# 576            DRB48       16.750
# 103            DRB48       16.750
# 5029           DRC01        5.920
# 2927           DRC01          NaN
# 2272           DRC01        5.920
# 5218           DRC01        5.920
# 1              DRC01        5.920
# 5077           DRC01        5.920
# 7557           DRC12       17.850
# 7062           DRC12       17.850
# 4605           DRC12       17.850
# 772            DRC12       17.850
# 1253           DRC13        8.260
# 5377           DRC13        8.260
# 2878           DRC13        8.260
# 2545           DRC13        8.260
# 4353           DRC24       17.850
# 7275           DRC24       17.850
# 6695           DRC25        5.730
# 2671           DRC25        5.730
# 6719           DRC25          NaN
# 4276           DRC25        5.730
# 6689           DRC25        5.730
# 2796           DRC25        5.730
# 1708           DRC25          NaN
# 7232           DRC27       13.800
# 3460           DRC27       13.800
# 1908           DRC27       13.800
# 211            DRC27       13.800
# 6656           DRC27       13.800
# 4730           DRC27       13.800
# 5479           DRC36       13.000
# 3594           DRC36       13.000
# 5633           DRC36       13.000
# 1084           DRC36          NaN
# 5899           DRC36       13.000
# 6301           DRC49        8.670
# 7419           DRC49        8.670
# 4835           DRC49          NaN
# 7933           DRD01       12.100
# 4609           DRD01       12.100
# 3816           DRD01       12.100
# 7842           DRD01       12.100
# 1796           DRD01       12.100
# 4442           DRD12        6.960
# 2591           DRD12        6.960
# 5308           DRD12        6.960
# 5637           DRD12        6.960
# 4273           DRD12        6.960
# 5149           DRD12        6.960
# 5043           DRD12          NaN
# 7313           DRD13          NaN
# 8150           DRD13       15.000
# 8332           DRD13       15.000
# 3339           DRD13       15.000
# 6582           DRD13       15.000
# 3860           DRD13       15.000
# 322            DRD13       15.000
# 1191           DRD15       10.600
# 3278           DRD15       10.600
# 3946           DRD15       10.600
# 4079           DRD15       10.600
# 4214           DRD15       10.600
# 2950           DRD15          NaN
# 6159           DRD15       10.600
# 7983           DRD24       13.850
# 1930           DRD24       13.850
# 5834           DRD24       13.850
# 1369           DRD24       13.850
# 3438           DRD24       13.850
# 158            DRD24       13.850
# 3094           DRD24          NaN
# 4193           DRD25          NaN
# 3020           DRD25        6.135
# 4886           DRD25        6.135
# 7604           DRD25        6.135
# 5762           DRD25        6.135
# 2212           DRD25        6.135
# 2766           DRD25          NaN
# 8071           DRD25        6.135
# 7602           DRD27          NaN
# 3821           DRD27       18.750
# 3728           DRD27       18.750
# 6047           DRD27       18.750
# 2273           DRD27       18.750
# 3796           DRD37        9.800
# 1686           DRD37        9.800
# 7122           DRD37        9.800
# 7908           DRD37        9.800
# 517            DRD37        9.800
# 4447           DRD37        9.800
# 4323           DRD37        9.800
# 3289           DRD49        9.895
# 5017           DRD49        9.895
# 2972           DRD49        9.895
# 813            DRD49        9.895
# 7223           DRD60       15.700
# 833            DRD60          NaN
# 1737           DRD60       15.700
# 7697           DRD60       15.700
# 6931           DRD60       15.700
# 7538           DRD60       15.700
# 3595           DRE01       10.100
# 7005           DRE01       10.100
# 7489           DRE03       19.600
# 5749           DRE03       19.600
# 2140           DRE03       19.600
# 4925           DRE03       19.600
# 2819           DRE03       19.600
# 1530           DRE03       19.600
# 2721           DRE03       19.600
# 3077           DRE12        4.590
# 7984           DRE12        4.590
# 1082           DRE12        4.590
# 1515           DRE12        4.590
# 884            DRE12          NaN
# 6432           DRE12        4.590
# 754            DRE13        6.280
# 7374           DRE13          NaN
# 1234           DRE13        6.280
# 2698           DRE13        6.280
# 4444           DRE13        6.280
# 7285           DRE15          NaN
# 4726           DRE15          NaN
# 3150           DRE15       13.350
# 2249           DRE15       13.350
# 1760           DRE15       13.350
# 2183           DRE15       13.350
# 8190           DRE25          NaN
# 577            DRE25       15.350
# 5532           DRE25       15.350
# 6256           DRE25       15.350
# 7352           DRE25       15.350
# 855            DRE27       11.850
# 5663           DRE27       11.850
# 2445           DRE27       11.850
# 2125           DRE27       11.850
# 4068           DRE27       11.850
# 1083           DRE27       11.850
# 5346           DRE37       13.500
# 6091           DRE37       13.500
# 1252           DRE37          NaN
# 3625           DRE37       13.500
# 8047           DRE37       13.500
# 2958           DRE48        8.430
# 2080           DRE48        8.430
# 2225           DRE48        8.430
# 5619           DRE48          NaN
# 3961           DRE48        8.430
# 8363           DRE48        8.430
# 6838           DRE48        8.430
# 2292           DRE49       20.750
# 389            DRE49       20.750
# 7874           DRE49       20.750
# 283            DRE49       20.750
# 2092           DRE49       20.750
# 4953           DRE49       20.750
# 2217           DRE49       20.750
# 4676           DRE49          NaN
# 2923           DRE49       20.750
# 915            DRE60        9.395
# 2699           DRE60        9.395
# 108            DRE60          NaN
# 304            DRE60        9.395
# 8028           DRE60        9.395
# 7283           DRE60        9.395
# 647            DRF01        5.655
# 5090           DRF01          NaN
# 7603           DRF01          NaN
# 4887           DRF01        5.655
# 3947           DRF01        5.655
# 6242           DRF01        5.655
# 4303           DRF01        5.655
# 4279           DRF01        5.655
# 6407           DRF03       19.100
# 2817           DRF03       19.100
# 2868           DRF03       19.100
# 561            DRF03       19.100
# 788            DRF03       19.100
# 8049           DRF03       19.100
# 4341           DRF03       19.100
# 1264           DRF03          NaN
# 6567           DRF13       12.100
# 6817           DRF13       12.100
# 4840           DRF13       12.100
# 6643           DRF13       12.100
# 1973           DRF13       12.100
# 7050           DRF13       12.100
# 653            DRF15       18.350
# 250            DRF15          NaN
# 7185           DRF15       18.350
# 4782           DRF15       18.350
# 3051           DRF23        4.610
# 2254           DRF23        4.610
# 966            DRF23        4.610
# 5493           DRF23        4.610
# 1412           DRF23        4.610
# 6335           DRF23        4.610
# 1043           DRF23          NaN
# 7559           DRF23        4.610
# 2568           DRF25        9.000
# 5835           DRF25        9.000
# 7763           DRF25          NaN
# 1989           DRF25          NaN
# 8048           DRF25        9.000
# 1364           DRF25        9.000
# 3119           DRF25        9.000
# 4946           DRF27        8.930
# 5294           DRF27          NaN
# 3929           DRF27        8.930
# 1262           DRF27        8.930
# 3832           DRF27        8.930
# 227            DRF27          NaN
# 6358           DRF27        8.930
# 8182           DRF27        8.930
# 1872           DRF36       16.100
# 1960           DRF36       16.100
# 207            DRF36       16.100
# 5093           DRF36       16.100
# 1103           DRF36       16.100
# 6606           DRF36          NaN
# 7459           DRF37       17.250
# 5011           DRF37       17.250
# 7478           DRF37          NaN
# 5210           DRF37       17.250
# 8506           DRF37       17.250
# 1463           DRF37       17.250
# 2797           DRF48        5.730
# 4861           DRF49          NaN
# 6759           DRF49        7.270
# 290            DRF49        7.270
# 4729           DRF49        7.270
# 1844           DRF49        7.270
# 163            DRF49        7.270
# 6743           DRF51       15.750
# 3085           DRF51       15.750
# 7306           DRF51       15.750
# 2218           DRF60       10.800
# 2054           DRF60       10.800
# 2189           DRF60       10.800
# 7952           DRF60       10.800
# 1218           DRG01       14.800
# 544            DRG01       14.800
# 5974           DRG01          NaN
# 3005           DRG01          NaN
# 8522           DRG01       14.800
# 6354           DRG03       14.500
# 1004           DRG03       14.500
# 8027           DRG03       14.500
# 8076           DRG03       14.500
# 4498           DRG03          NaN
# 2917           DRG11        6.385
# 1243           DRG11        6.385
# 6870           DRG11        6.385
# 4034           DRG11        6.385
# 2597           DRG11        6.385
# 5323           DRG13       17.250
# 3027           DRG13       17.250
# 6428           DRG13       17.250
# 4292           DRG13       17.250
# 8487           DRG13          NaN
# 6240           DRG15        6.130
# 4642           DRG15        6.130
# 4653           DRG15        6.130
# 7286           DRG15        6.130
# 842            DRG15        6.130
# 1406           DRG15        6.130
# 8253           DRG23        8.880
# 2705           DRG23        8.880
# 5107           DRG23        8.880
# 128            DRG23        8.880
# 7264           DRG23        8.880
# 2357           DRG23          NaN
# 2575           DRG23        8.880
# 5531           DRG25       10.500
# 5969           DRG25       10.500
# 5537           DRG27        8.895
# 2298           DRG27        8.895
# 3940           DRG27          NaN
# 91             DRG27        8.895
# 1063           DRG27        8.895
# 6510           DRG36       14.150
# 6816           DRG36       14.150
# 4446           DRG36       14.150
# 6103           DRG36       14.150
# 6399           DRG36          NaN
# 5247           DRG37       16.200
# 3374           DRG37       16.200
# 6875           DRG37          NaN
# 2998           DRG37       16.200
# 2300           DRG37       16.200
# 1986           DRG37       16.200
# 7830           DRG37       16.200
# 5220           DRG39       14.150
# 4572           DRG39       14.150
# 643            DRG39       14.150
# 2424           DRG48          NaN
# 2460           DRG48        5.780
# 1931           DRG48        5.780
# 3972           DRG48        5.780
# 2169           DRG48        5.780
# 6682           DRG49        7.810
# 1414           DRG49          NaN
# 7261           DRG49        7.810
# 4800           DRG49        7.810
# 1879           DRG49        7.810
# 1282           DRG51       12.100
# 4617           DRG51       12.100
# 3451           DRG51       12.100
# 7469           DRG51       12.100
# 908            DRG51       12.100
# 5545           DRH01       17.500
# 34             DRH01       17.500
# 7801           DRH01       17.500
# 7186           DRH01          NaN
# 1177           DRH01          NaN
# 2449           DRH03       17.250
# 6595           DRH03       17.250
# 433            DRH03          NaN
# 6800           DRH03       17.250
# 3300           DRH03       17.250
# 3074           DRH03       17.250
# 6527           DRH11        5.980
# 4993           DRH11        5.980
# 5075           DRH11          NaN
# 3079           DRH11        5.980
# 6288           DRH13        8.575
# 2486           DRH13          NaN
# 6603           DRH13        8.575
# 560            DRH13        8.575
# 8276           DRH13        8.575
# 1620           DRH15        8.775
# 3948           DRH15          NaN
# 4111           DRH15        8.775
# 447            DRH15        8.775
# 1626           DRH23       14.650
# 5695           DRH23       14.650
# 6634           DRH23       14.650
# 1061           DRH23       14.650
# 3540           DRH23          NaN
# 2606           DRH25       18.700
# 6658           DRH25       18.700
# 8140           DRH25       18.700
# 2115           DRH25       18.700
# 5820           DRH25       18.700
# 700            DRH25          NaN
# 3302           DRH36       16.200
# 6611           DRH36          NaN
# 2022           DRH36       16.200
# 3037           DRH36       16.200
# 4557           DRH36       16.200
# 6970           DRH36       16.200
# 1185           DRH37          NaN
# 3282           DRH37       17.600
# 7020           DRH37       17.600
# 68             DRH37       17.600
# 2789           DRH37       17.600
# 5478           DRH37       17.600
# 330            DRH39       20.700
# 6330           DRH39       20.700
# 7709           DRH39       20.700
# 4076           DRH39          NaN
# 8404           DRH39          NaN
# 5945           DRH39       20.700
# 2781           DRH49       19.700
# 2733           DRH49       19.700
# 3852           DRH49       19.700
# 1204           DRH49          NaN
# 1472           DRH51          NaN
# 1456           DRH51       17.600
# 7815           DRH51          NaN
# 5865           DRH51       17.600
# 7160           DRH51       17.600
# 8241           DRH59       10.800
# 1146           DRH59       10.800
# 1883           DRH59       10.800
# 4141           DRI01          NaN
# 3307           DRI01        7.970
# 4481           DRI01        7.970
# 3597           DRI01        7.970
# 2616           DRI01        7.970
# 4291           DRI01        7.970
# 353            DRI01        7.970
# 3725           DRI03        6.030
# 5422           DRI03        6.030
# 6848           DRI03        6.030
# 3887           DRI03        6.030
# 6671           DRI03          NaN
# 7341           DRI03        6.030
# 4594           DRI03          NaN
# 4330           DRI03        6.030
# 8483           DRI11        8.260
# 1366           DRI11          NaN
# 3127           DRI11        8.260
# 5310           DRI11        8.260
# 7192           DRI11        8.260
# 7022           DRI11        8.260
# 18             DRI11          NaN
# 1373           DRI13       15.350
# 5863           DRI13       15.350
# 3069           DRI13       15.350
# 435            DRI13       15.350
# 4161           DRI23       18.850
# 4169           DRI23       18.850
# 7841           DRI23       18.850
# 4230           DRI23       18.850
# 2322           DRI23          NaN
# 7479           DRI23       18.850
# 6667           DRI25          NaN
# 1452           DRI25       19.600
# 4285           DRI25       19.600
# 6023           DRI25       19.600
# 4934           DRI25       19.600
# 6862           DRI25       19.600
# 92             DRI25       19.600
# 3216           DRI37       15.850
# 345            DRI37       15.850
# 3981           DRI37       15.850
# 630            DRI37          NaN
# 1811           DRI37       15.850
# 3839           DRI37       15.850
# 4549           DRI39       13.800
# 5763           DRI39          NaN
# 1207           DRI39       13.800
# 4238           DRI39       13.800
# 712            DRI39       13.800
# 7958           DRI47       14.700
# 3990           DRI47       14.700
# 1692           DRI47       14.700
# 8225           DRI47       14.700
# 8473           DRI47       14.700
# 4792           DRI47       14.700
# 6020           DRI49       14.150
# 6830           DRI49       14.150
# 2882           DRI49       14.150
# 126            DRI49       14.150
# 4206           DRI51       17.250
# 5893           DRI51       17.250
# 7620           DRI51          NaN
# 464            DRI51       17.250
# 6627           DRI51       17.250
# 1072           DRI51       17.250
# 4563           DRI59        9.500
# 5954           DRI59          NaN
# 2787           DRJ01        6.135
# 2640           DRJ01        6.135
# 7500           DRJ01        6.135
# 6999           DRJ01        6.135
# 3960           DRJ01        6.135
# 7666           DRJ01          NaN
# 7266           DRJ11        9.500
# 6201           DRJ11        9.500
# 5268           DRJ11        9.500
# 2017           DRJ11        9.500
# 6995           DRJ11        9.500
# 5978           DRJ11        9.500
# 6745           DRJ11        9.500
# 8434           DRJ13       12.650
# 224            DRJ13       12.650
# 1988           DRJ13       12.650
# 121            DRJ13       12.650
# 6006           DRJ13       12.650
# 2952           DRJ13       12.650
# 3956           DRJ23          NaN
# 5681           DRJ23       18.350
# 7178           DRJ23       18.350
# 2294           DRJ23       18.350
# 3118           DRJ23       18.350
# 6494           DRJ24       11.800
# 829            DRJ24       11.800
# 2401           DRJ24          NaN
# 6921           DRJ24       11.800
# 6168           DRJ24       11.800
# 4218           DRJ24       11.800
# 1340           DRJ24       11.800
# 2174           DRJ24       11.800
# 8418           DRJ25       14.600
# 150            DRJ25       14.600
# 5587           DRJ25       14.600
# 4241           DRJ25       14.600
# 8111           DRJ35       10.100
# 617            DRJ35       10.100
# 5658           DRJ35       10.100
# 2148           DRJ37       10.800
# 5039           DRJ37          NaN
# 1220           DRJ37       10.800
# 2165           DRJ39       20.250
# 998            DRJ39       20.250
# 7256           DRJ39       20.250
# 7892           DRJ39       20.250
# 2344           DRJ39       20.250
# 3009           DRJ39          NaN
# 6456           DRJ47       18.250
# 1996           DRJ47          NaN
# 5367           DRJ47       18.250
# 4623           DRJ47       18.250
# 1602           DRJ49        6.865
# 6512           DRJ49        6.865
# 4365           DRJ49        6.865
# 8484           DRJ49        6.865
# 8402           DRJ49        6.865
# 5550           DRJ51       14.100
# 6898           DRJ51       14.100
# 244            DRJ51       14.100
# 6138           DRJ51       14.100
# 3198           DRJ51       14.100
# 7969           DRJ59       11.650
# 2484           DRJ59          NaN
# 5049           DRJ59       11.650
# 3296           DRJ59       11.650
# 4035           DRJ59       11.650
# 27             DRJ59       11.650
# 1446           DRK01        7.630
# 7520           DRK01        7.630
# 261            DRK01        7.630
# 4858           DRK01        7.630
# 1935           DRK01        7.630
# 5606           DRK11          NaN
# 6602           DRK11        8.210
# 4862           DRK11        8.210
# 1810           DRK11        8.210
# 994            DRK11        8.210
# 6681           DRK11        8.210
# 7990           DRK12        9.500
# 906            DRK12        9.500
# 6958           DRK12        9.500
# 153            DRK12          NaN
# 4304           DRK12        9.500
# 8038           DRK12        9.500
# 2135           DRK12        9.500
# 210            DRK12        9.500
# 1360           DRK13       11.800
# 5221           DRK13       11.800
# 3437           DRK13       11.800
# 1339           DRK13       11.800
# 2961           DRK13          NaN
# 2772           DRK13       11.800
# 670            DRK23        8.395
# 732            DRK23        8.395
# 3087           DRK23        8.395
# 5474           DRK23        8.395
# 3062           DRK23          NaN
# 5566           DRK35        8.365
# 7633           DRK35        8.365
# 2492           DRK35          NaN
# 7477           DRK35        8.365
# 574            DRK35          NaN
# 815            DRK35        8.365
# 3905           DRK35        8.365
# 57             DRK35        8.365
# 3687           DRK37        5.000
# 1046           DRK37          NaN
# 599            DRK37        5.000
# 8485           DRK37          NaN
# 7568           DRK37        5.000
# 7719           DRK39        7.020
# 773            DRK39        7.020
# 6529           DRK39        7.020
# 5046           DRK39        7.020
# 5951           DRK39          NaN
# 2059           DRK47        7.905
# 4432           DRK47        7.905
# 7584           DRK47        7.905
# 1685           DRK47        7.905
# 3989           DRK47        7.905
# 109            DRK49       14.150
# 2827           DRK49          NaN
# 1913           DRK49          NaN
# 5443           DRK49       14.150
# 8325           DRK49       14.150
# 3340           DRK49       14.150
# 1561           DRK49       14.150
# 4394           DRK59        8.895
# 4807           DRK59        8.895
# 6167           DRK59        8.895
# 3706           DRK59          NaN
# 481            DRK59        8.895
# 4217           DRK59        8.895
# 165            DRL01       19.500
# 2065           DRL01       19.500
# 6098           DRL01       19.500
# 1667           DRL01       19.500
# 2794           DRL01          NaN
# 4772           DRL01          NaN
# 2040           DRL01       19.500
# 925            DRL11       10.500
# 1774           DRL11          NaN
# 1597           DRL11       10.500
# 6927           DRL11       10.500
# 1780           DRL11       10.500
# 3730           DRL23       18.350
# 8297           DRL23       18.350
# 3671           DRL23       18.350
# 515            DRL23       18.350
# 2340           DRL35       15.700
# 4379           DRL35       15.700
# 2393           DRL35       15.700
# 3102           DRL35       15.700
# 8118           DRL35       15.700
# 2003           DRL35       15.700
# 6605           DRL35          NaN
# 5400           DRL37       15.500
# 7189           DRL37       15.500
# 6662           DRL37       15.500
# 4531           DRL37       15.500
# 940            DRL37       15.500
# 3418           DRL37       15.500
# 5703           DRL37          NaN
# 4553           DRL47       19.700
# 6559           DRL47       19.700
# 5267           DRL47          NaN
# 6104           DRL47       19.700
# 2175           DRL47       19.700
# 7725           DRL49       13.150
# 8399           DRL49       13.150
# 6222           DRL49       13.150
# 5873           DRL49       13.150
# 3433           DRL49       13.150
# 3310           DRL49       13.150
# 8090           DRL59          NaN
# 4191           DRL59       16.750
# 6460           DRL60        8.520
# 7753           DRL60          NaN
# 6609           DRL60        8.520
# 6436           DRL60        8.520
# 2288           DRL60        8.520
# 4996           DRL60        8.520
# 3146           DRL60        8.520
# 6837           DRM11        6.570
# 5569           DRM11        6.570
# 565            DRM11        6.570
# 4308           DRM23       16.600
# 5396           DRM23       16.600
# 5444           DRM23          NaN
# 1237           DRM23       16.600
# 4359           DRM23       16.600
# 1272           DRM23       16.600
# 6391           DRM23       16.600
# 2085           DRM35        9.695
# 4933           DRM35        9.695
# 1189           DRM35        9.695
# 6688           DRM35          NaN
# 1393           DRM37          NaN
# 7978           DRM37       15.350
# 3142           DRM37       15.350
# 5418           DRM37       15.350
# 913            DRM37       15.350
# 6238           DRM37          NaN
# 5315           DRM37       15.350
# 4771           DRM47        9.300
# 2891           DRM47        9.300
# 235            DRM47          NaN
# 3486           DRM47        9.300
# 7804           DRM47        9.300
# 6089           DRM47        9.300
# 1725           DRM48       15.200
# 879            DRM48       15.200
# 5817           DRM48       15.200
# 3660           DRM48          NaN
# 6081           DRM49        6.110
# 5751           DRM49        6.110
# 6959           DRM49        6.110
# 6497           DRM49        6.110
# 4535           DRM49        6.110
# 2374           DRM59        5.880
# 3862           DRM59        5.880
# 6847           DRM59        5.880
# 4499           DRM59        5.880
# 7551           DRM59          NaN
# 858            DRM59          NaN
# 7464           DRM59        5.880
# 8346           DRN11        7.850
# 1047           DRN11        7.850
# 5756           DRN11        7.850
# 4066           DRN11        7.850
# 8116           DRN35        8.010
# 6922           DRN35        8.010
# 3965           DRN35        8.010
# 7565           DRN35        8.010
# 7733           DRN35        8.010
# 7637           DRN35        8.010
# 4949           DRN36          NaN
# 8156           DRN36       15.200
# 1147           DRN36       15.200
# 3116           DRN36       15.200
# 509            DRN36          NaN
# 3356           DRN37        9.600
# 3103           DRN37        9.600
# 7473           DRN37        9.600
# 6183           DRN37        9.600
# 7599           DRN37        9.600
# 5786           DRN37        9.600
# 8100           DRN47       12.100
# 3672           DRN47       12.100
# 360            DRN47       12.100
# 746            DRN47       12.100
# 2676           DRN47       12.100
# 3550           DRN47          NaN
# 1762           DRN47       12.100
# 6900           DRN47       12.100
# 7434           DRN47       12.100
# 1381           DRN59       15.000
# 7138           DRN59       15.000
# 2811           DRN59       15.000
# 4759           DRN59          NaN
# 6649           DRO35       13.850
# 4526           DRO35       13.850
# 1471           DRO35       13.850
# 1956           DRO35       13.850
# 8414           DRO47       10.195
# 2813           DRO47       10.195
# 3751           DRO47       10.195
# 4003           DRO47       10.195
# 2146           DRO47       10.195
# 4503           DRO47       10.195
# 6811           DRO59          NaN
# 3587           DRO59       11.800
# 7084           DRO59       11.800
# 3188           DRO59       11.800
# 5291           DRP35       18.850
# 820            DRP35       18.850
# 3988           DRP35       18.850
# 1701           DRP35          NaN
# 3270           DRP35       18.850
# 409            DRP35          NaN
# 7957           DRP35       18.850
# 4356           DRP35       18.850
# 3184           DRP47       15.750
# 305            DRP47       15.750
# 4106           DRP47       15.750
# 6932           DRP47       15.750
# 2560           DRQ35        9.300
# 8167           DRQ35        9.300
# 7046           DRQ35        9.300
# 3980           DRQ35        9.300
# 5883           DRQ35        9.300
# 7948           DRQ35        9.300
# 320            DRQ35          NaN
# 178            DRY23          NaN
# 7094           DRY23        9.395
# 1226           DRY23        9.395
# 2581           DRY23          NaN
# 5080           DRY23        9.395
# 2724           DRY23        9.395
# 4207           DRZ11          NaN
# 4339           DRZ11        8.850
# 6623           DRZ11        8.850
# 8396           DRZ11        8.850
# 3539           DRZ11        8.850
# 37             DRZ11        8.850
# 1241           DRZ24        7.535
# 1782           DRZ24        7.535
# 4542           DRZ24        7.535
# 4146           DRZ24        7.535
# 2522           DRZ24          NaN
# 8372           FDA01          NaN
# 8514           FDA01       15.000
# 311            FDA01       15.000
# 748            FDA01       15.000
# 7133           FDA01       15.000
# 5439           FDA01       15.000
# 1860           FDA01       15.000
# 3507           FDA02          NaN
# 5018           FDA02       14.000
# 2402           FDA02          NaN
# 6250           FDA02       14.000
# 1219           FDA02       14.000
# 1735           FDA02       14.000
# 5538           FDA02       14.000
# 747            FDA03       18.500
# 11             FDA03       18.500
# 7772           FDA03       18.500
# 721            FDA03          NaN
# 5772           FDA03       18.500
# 1951           FDA03       18.500
# 1409           FDA04          NaN
# 5572           FDA04       11.300
# 2622           FDA04       11.300
# 1901           FDA04       11.300
# 5389           FDA04       11.300
# 3022           FDA04       11.300
# 6132           FDA04       11.300
# 5602           FDA04       11.300
# 6552           FDA07        7.550
# 7512           FDA07        7.550
# 8132           FDA07        7.550
# 3679           FDA07        7.550
# 4493           FDA07          NaN
# 3345           FDA07        7.550
# 3897           FDA07        7.550
# 7220           FDA08          NaN
# 7876           FDA08       11.850
# 3355           FDA08       11.850
# 3619           FDA08       11.850
# 7707           FDA08          NaN
# 192            FDA08       11.850
# 808            FDA09       13.350
# 6554           FDA09       13.350
# 6748           FDA09       13.350
# 6789           FDA09       13.350
# 4648           FDA09       13.350
# 737            FDA10       20.350
# 3306           FDA10          NaN
# 6127           FDA10       20.350
# 1827           FDA10          NaN
# 3343           FDA10       20.350
# 1435           FDA10       20.350
# 2321           FDA11        7.750
# 6604           FDA11        7.750
# 6521           FDA11        7.750
# 8316           FDA11        7.750
# 5682           FDA11          NaN
# 5171           FDA13       15.850
# 8227           FDA13       15.850
# 6507           FDA13       15.850
# 7644           FDA13          NaN
# 5670           FDA13          NaN
# 6386           FDA13       15.850
# 3479           FDA13       15.850
# 461            FDA13       15.850
# 3850           FDA14       16.100
# 5727           FDA14       16.100
# 715            FDA14          NaN
# 2599           FDA15        9.300
# 2643           FDA15        9.300
# 7543           FDA15        9.300
# 4874           FDA15        9.300
# 5413           FDA15        9.300
# 6696           FDA15          NaN
# 0              FDA15        9.300
# 831            FDA15        9.300
# 1627           FDA16          NaN
# 536            FDA16        6.695
# 5130           FDA16        6.695
# 4051           FDA16        6.695
# 8365           FDA19        7.520
# 4108           FDA19          NaN
# 5788           FDA19        7.520
# 4869           FDA19        7.520
# 3512           FDA19        7.520
# 5920           FDA20          NaN
# 1714           FDA20        6.780
# 1461           FDA20        6.780
# 1777           FDA20        6.780
# 2057           FDA20        6.780
# 1552           FDA20        6.780
# 6409           FDA21       13.650
# 4565           FDA21       13.650
# 4203           FDA21       13.650
# 826            FDA21       13.650
# 8012           FDA21       13.650
# 6876           FDA21       13.650
# 6293           FDA22          NaN
# 8426           FDA22        7.435
# 2736           FDA22        7.435
# 7783           FDA23          NaN
# 1357           FDA23        9.800
# 709            FDA23        9.800
# 6703           FDA23        9.800
# 6756           FDA23        9.800
# 1869           FDA23        9.800
# 7289           FDA25       16.500
# 8298           FDA25       16.500
# 4107           FDA25       16.500
# 6797           FDA25       16.500
# 1582           FDA25       16.500
# 4028           FDA26          NaN
# 6905           FDA26        7.855
# 5101           FDA26          NaN
# 4278           FDA26        7.855
# 1164           FDA26        7.855
# 2440           FDA27       20.350
# 3461           FDA27       20.350
# 423            FDA27       20.350
# 6353           FDA27       20.350
# 3630           FDA27       20.350
# 2884           FDA28          NaN
# 8262           FDA28       16.100
# 2351           FDA28       16.100
# 3506           FDA28       16.100
# 1174           FDA28       16.100
# 7889           FDA28       16.100
# 6937           FDA31        7.100
# 2834           FDA31        7.100
# 2221           FDA31        7.100
# 6130           FDA31        7.100
# 3979           FDA32       14.000
# 6878           FDA32       14.000
# 1950           FDA32       14.000
# 3913           FDA32       14.000
# 8367           FDA32          NaN
# 3771           FDA32       14.000
# 6864           FDA32       14.000
# 7142           FDA33        6.480
# 316            FDA33        6.480
# 1661           FDA33        6.480
# 3067           FDA33        6.480
# 2737           FDA33        6.480
# 4883           FDA34       11.500
# 1059           FDA34       11.500
# 661            FDA34          NaN
# 8360           FDA34       11.500
# 5645           FDA34       11.500
# 2831           FDA35       14.850
# 7589           FDA35       14.850
# 7381           FDA35          NaN
# 6121           FDA35       14.850
# 2598           FDA36          NaN
# 6483           FDA36          NaN
# 471            FDA36        5.985
# 7241           FDA36        5.985
# 4801           FDA37        7.810
# 6739           FDA37        7.810
# 3106           FDA37        7.810
# 2227           FDA38        5.440
# 1909           FDA38        5.440
# 2035           FDA38          NaN
# 6331           FDA38        5.440
# 1543           FDA39        6.320
# 219            FDA39        6.320
# 3764           FDA39        6.320
# 2354           FDA39        6.320
# 1631           FDA39        6.320
# 5649           FDA39          NaN
# 6473           FDA39        6.320
# 1927           FDA39        6.320
# 498            FDA40       16.000
# 2847           FDA40       16.000
# 1630           FDA40       16.000
# 4286           FDA40       16.000
# 6245           FDA40       16.000
# 941            FDA43       10.895
# 8421           FDA43       10.895
# 5843           FDA43          NaN
# 53             FDA43       10.895
# 4780           FDA43       10.895
# 540            FDA44       19.700
# 3822           FDA44          NaN
# 93             FDA44       19.700
# 673            FDA44       19.700
# 2709           FDA44       19.700
# 6046           FDA44       19.700
# 2909           FDA44       19.700
# 8431           FDA44       19.700
# 6705           FDA45       21.250
# 5782           FDA45       21.250
# 6101           FDA45       21.250
# 148            FDA45       21.250
# 965            FDA45          NaN
# 1368           FDA46       13.600
# 5144           FDA46          NaN
# 834            FDA46       13.600
# 6972           FDA46       13.600
# 42             FDA46       13.600
# 5348           FDA46       13.600
# 4316           FDA47       10.500
# 801            FDA47       10.500
# 2437           FDA47          NaN
# 5793           FDA47       10.500
# 106            FDA47       10.500
# 7552           FDA47       10.500
# 2457           FDA48       12.100
# 1967           FDA48       12.100
# 1330           FDA49       19.700
# 7640           FDA49       19.700
# 6487           FDA49       19.700
# 1129           FDA49          NaN
# 5163           FDA49          NaN
# 3108           FDA49       19.700
# 4701           FDA50       16.250
# 2697           FDA50       16.250
# 2889           FDA50          NaN
# 1167           FDA50       16.250
# 6329           FDA50       16.250
# 4554           FDA50          NaN
# 7422           FDA50       16.250
# 4825           FDA50       16.250
# 863            FDA51        8.050
# 5981           FDA51        8.050
# 1240           FDA51          NaN
# 4188           FDA52       16.200
# 8257           FDA52       16.200
# 896            FDA52       16.200
# 6575           FDA52          NaN
# 8085           FDA52       16.200
# 3509           FDA55       17.200
# 5404           FDA55          NaN
# 7780           FDA55          NaN
# 5918           FDA55       17.200
# 1281           FDA56        9.210
# 1892           FDA56        9.210
# 6914           FDA56        9.210
# 4099           FDA56        9.210
# 6404           FDA56          NaN
# 6060           FDA57       18.850
# 2959           FDA57          NaN
# 3459           FDA57       18.850
# 3464           FDA58        9.395
# 7685           FDA58        9.395
# 5181           FDA58        9.395
# 6160           FDB02        9.695
# 2319           FDB02        9.695
# 1587           FDB02        9.695
# 3174           FDB02        9.695
# 4913           FDB02          NaN
# 5121           FDB03       17.750
# 8280           FDB03       17.750
# 4718           FDB03       17.750
# 3974           FDB03       17.750
# 6780           FDB03       17.750
# 1816           FDB04       11.350
# 5857           FDB04          NaN
# 1426           FDB04       11.350
# 7398           FDB04       11.350
# 3664           FDB04       11.350
# 3023           FDB04          NaN
# 2773           FDB04       11.350
# 1175           FDB05        5.155
# 4583           FDB05          NaN
# 7651           FDB05        5.155
# 5697           FDB05          NaN
# 1558           FDB08        6.055
# 4179           FDB08        6.055
# 3958           FDB08        6.055
# 8285           FDB08        6.055
# 4728           FDB08          NaN
# 1550           FDB08        6.055
# 7414           FDB09       16.250
# 8405           FDB09          NaN
# 3966           FDB09       16.250
# 5858           FDB09       16.250
# 807            FDB09       16.250
# 4890           FDB10       10.000
# 8347           FDB10       10.000
# 1293           FDB11       16.000
# 6840           FDB11       16.000
# 146            FDB11       16.000
# 5237           FDB11       16.000
# 439            FDB11       16.000
# 4343           FDB12       11.150
# 1856           FDB12       11.150
# 3524           FDB12       11.150
# 6651           FDB12       11.150
# 1662           FDB12       11.150
# 4295           FDB14          NaN
# 1215           FDB14       20.250
# 4637           FDB14          NaN
# 5251           FDB14       20.250
# 5490           FDB14       20.250
# 122            FDB14       20.250
# 457            FDB14       20.250
# 1682           FDB15       10.895
# 7069           FDB15       10.895
# 895            FDB15       10.895
# 4396           FDB15       10.895
# 7951           FDB15       10.895
# 1506           FDB15       10.895
# 502            FDB15       10.895
# 3936           FDB16        8.210
# 8330           FDB16        8.210
# 672            FDB16        8.210
# 3043           FDB16        8.210
# 7834           FDB16        8.210
# 8461           FDB17       13.150
# 421            FDB17       13.150
# 1497           FDB17       13.150
# 2107           FDB17       13.150
# 2023           FDB17       13.150
# 4560           FDB17          NaN
# 5509           FDB17       13.150
# 5761           FDB17          NaN
# 2700           FDB20        7.720
# 8468           FDB20        7.720
# 6530           FDB20        7.720
# 8259           FDB20        7.720
# 2284           FDB20        7.720
# 625            FDB21        7.475
# 8146           FDB21        7.475
# 6868           FDB21        7.475
# 306            FDB21        7.475
# 1113           FDB21          NaN
# 5380           FDB22          NaN
# 2345           FDB22        8.020
# 1201           FDB22        8.020
# 1095           FDB22        8.020
# 5655           FDB22        8.020
# 8186           FDB23       19.200
# 7993           FDB23       19.200
# 4393           FDB23       19.200
# 6221           FDB23          NaN
# 3851           FDB23          NaN
# 1825           FDB23       19.200
# 4194           FDB26       14.000
# 7425           FDB26          NaN
# 3815           FDB26       14.000
# 2168           FDB26       14.000
# 1010           FDB26       14.000
# 4098           FDB27        7.575
# 1937           FDB27        7.575
# 376            FDB27        7.575
# 6761           FDB27          NaN
# 5740           FDB27        7.575
# 5430           FDB27        7.575
# 3122           FDB28        6.615
# 4228           FDB28        6.615
# 7480           FDB28        6.615
# 6053           FDB28        6.615
# 314            FDB29       16.700
# 5141           FDB29       16.700
# 6187           FDB29       16.700
# 3169           FDB29       16.700
# 437            FDB29       16.700
# 3614           FDB29       16.700
# 4906           FDB32       20.600
# 2710           FDB32       20.600
# 3076           FDB32          NaN
# 5995           FDB32       20.600
# 8263           FDB32          NaN
# 5066           FDB32       20.600
# 5373           FDB33       17.750
# 4716           FDB33       17.750
# 1318           FDB33       17.750
# 5860           FDB33          NaN
# 2852           FDB33       17.750
# 3569           FDB34       15.250
# 950            FDB34       15.250
# 7915           FDB34       15.250
# 385            FDB34       15.250
# 1144           FDB34       15.250
# 39             FDB34          NaN
# 2629           FDB34       15.250
# 4441           FDB35       12.300
# 237            FDB35       12.300
# 5134           FDB35       12.300
# 6208           FDB35          NaN
# 2904           FDB35       12.300
# 176            FDB35       12.300
# 7814           FDB36        5.465
# 2658           FDB36        5.465
# 4270           FDB36        5.465
# 1544           FDB36        5.465
# 4839           FDB36          NaN
# 6721           FDB36        5.465
# 156            FDB36        5.465
# 2776           FDB37       20.250
# 4731           FDB37       20.250
# 5821           FDB37          NaN
# 1307           FDB37       20.250
# 2103           FDB37       20.250
# 5654           FDB38          NaN
# 2726           FDB38       19.500
# 749            FDB38       19.500
# 545            FDB38          NaN
# 6443           FDB38       19.500
# 7051           FDB39       11.600
# 6836           FDB39          NaN
# 3858           FDB39       11.600
# 971            FDB39       11.600
# 3838           FDB39       11.600
# 4636           FDB40       17.500
# 4123           FDB40       17.500
# 3806           FDB40       17.500
# 7622           FDB40       17.500
# 1045           FDB40       17.500
# 5153           FDB40          NaN
# 196            FDB41       19.000
# 5269           FDB41       19.000
# 2408           FDB41       19.000
# 6869           FDB41          NaN
# 6033           FDB41       19.000
# 5810           FDB41       19.000
# 1581           FDB44        6.655
# 936            FDB44        6.655
# 8008           FDB44        6.655
# 5800           FDB44          NaN
# 418            FDB44        6.655
# 5258           FDB45       20.850
# 4345           FDB45       20.850
# 6326           FDB45       20.850
# 5825           FDB45          NaN
# 324            FDB45       20.850
# 6538           FDB45       20.850
# 5690           FDB46       10.500
# 6097           FDB46       10.500
# 8505           FDB46       10.500
# 8453           FDB46       10.500
# 3166           FDB47        8.800
# 4714           FDB47        8.800
# 2233           FDB49        8.300
# 4298           FDB49          NaN
# 2498           FDB49        8.300
# 8081           FDB49        8.300
# 8284           FDB49        8.300
# 4412           FDB49        8.300
# 4325           FDB50       13.000
# 4496           FDB50       13.000
# 4916           FDB50       13.000
# 5235           FDB50       13.000
# 3412           FDB50       13.000
# 137            FDB51        6.920
# 1286           FDB51        6.920
# 3295           FDB51        6.920
# 3694           FDB51        6.920
# 5564           FDB51        6.920
# 8386           FDB51        6.920
# 4027           FDB52          NaN
# 3577           FDB52       17.750
# 2964           FDB52       17.750
# 7555           FDB52       17.750
# 6471           FDB52       17.750
# 8099           FDB53          NaN
# 318            FDB53       13.350
# 534            FDB53       13.350
# 4534           FDB53       13.350
# 4160           FDB53       13.350
# 2082           FDB56        8.750
# 5665           FDB56          NaN
# 5480           FDB56        8.750
# 99             FDB56        8.750
# 7560           FDB56        8.750
# 97             FDB56        8.750
# 656            FDB56        8.750
# 8004           FDB57       20.250
# 8331           FDB57       20.250
# 288            FDB57       20.250
# 1700           FDB57          NaN
# 5601           FDB57       20.250
# 3840           FDB58       10.500
# 3726           FDB58          NaN
# 2513           FDB58       10.500
# 1962           FDB58          NaN
# 7693           FDB58       10.500
# 2252           FDB58       10.500
# 1385           FDB58       10.500
# 2008           FDB59       18.250
# 1641           FDB59       18.250
# 743            FDB59       18.250
# 3748           FDB59       18.250
# 6451           FDB59          NaN
# 6233           FDB60        9.300
# 6525           FDB60        9.300
# 3239           FDB60        9.300
# 1459           FDB60        9.300
# 3063           FDB60        9.300
# 7282           FDB60        9.300
# 2320           FDC02          NaN
# 2368           FDC02       21.350
# 4468           FDC02       21.350
# 2802           FDC02       21.350
# 43             FDC02       21.350
# 483            FDC02       21.350
# 7319           FDC03        8.575
# 2118           FDC03        8.575
# 4907           FDC03        8.575
# 1615           FDC03        8.575
# 1553           FDC04          NaN
# 7525           FDC04       15.600
# 758            FDC04          NaN
# 8074           FDC04       15.600
# 3921           FDC04       15.600
# 1482           FDC05       13.100
# 2483           FDC05       13.100
# 1926           FDC05       13.100
# 8477           FDC05       13.100
# 7909           FDC08       19.000
# 2828           FDC08       19.000
# 5826           FDC08          NaN
# 317            FDC08       19.000
# 528            FDC08       19.000
# 2278           FDC08       19.000
# 4844           FDC09       15.500
# 8202           FDC09       15.500
# 2704           FDC09       15.500
# 921            FDC09       15.500
# 1169           FDC09       15.500
# 1433           FDC10        9.800
# 3415           FDC10        9.800
# 3800           FDC10        9.800
# 1807           FDC10          NaN
# 771            FDC10          NaN
# 610            FDC11          NaN
# 4125           FDC11       20.500
# 5371           FDC11       20.500
# 5797           FDC11       20.500
# 29             FDC14          NaN
# 5760           FDC14       14.500
# 4297           FDC14       14.500
# 7031           FDC14       14.500
# 6478           FDC14       14.500
# 6346           FDC14       14.500
# 3609           FDC14       14.500
# 6257           FDC14          NaN
# 415            FDC15       18.100
# 521            FDC15       18.100
# 8159           FDC15       18.100
# 533            FDC15       18.100
# 3719           FDC16       11.500
# 6571           FDC16       11.500
# 7007           FDC16       11.500
# 2626           FDC16       11.500
# 8189           FDC16       11.500
# 5207           FDC16       11.500
# 7837           FDC16          NaN
# 6149           FDC17       12.150
# 1802           FDC17       12.150
# 5340           FDC17       12.150
# 2539           FDC17       12.150
# 2427           FDC17       12.150
# 7752           FDC17          NaN
# 582            FDC17       12.150
# 5557           FDC20       10.650
# 4833           FDC20       10.650
# 4392           FDC20          NaN
# 5096           FDC20       10.650
# 6548           FDC20       10.650
# 1978           FDC20       10.650
# 2342           FDC21       14.600
# 6857           FDC21       14.600
# 7000           FDC21       14.600
# 6356           FDC21       14.600
# 1078           FDC21          NaN
# 5715           FDC22        6.890
# 3592           FDC22        6.890
# 6355           FDC22        6.890
# 6664           FDC22        6.890
# 3820           FDC22        6.890
# 3185           FDC23       18.000
# 983            FDC26       10.195
# 1008           FDC26       10.195
# 5366           FDC26       10.195
# 5073           FDC26       10.195
# 4984           FDC26       10.195
# 6339           FDC28        7.905
# 7274           FDC28        7.905
# 6186           FDC28          NaN
# 1758           FDC28          NaN
# 8450           FDC28        7.905
# 7146           FDC29        8.390
# 75             FDC29        8.390
# 4944           FDC29        8.390
# 1011           FDC29        8.390
# 1820           FDC29        8.390
# 5118           FDC29          NaN
# 1982           FDC29        8.390
# 6107           FDC32       18.350
# 5103           FDC32          NaN
# 1249           FDC32       18.350
# 2346           FDC32       18.350
# 7466           FDC32          NaN
# 1837           FDC33        8.960
# 694            FDC33          NaN
# 5574           FDC33        8.960
# 1944           FDC33        8.960
# 3453           FDC33        8.960
# 5986           FDC33        8.960
# 7880           FDC34       16.000
# 4904           FDC34       16.000
# 3992           FDC34       16.000
# 7078           FDC34       16.000
# 5201           FDC34       16.000
# 5732           FDC34          NaN
# 614            FDC35        7.435
# 1942           FDC35        7.435
# 8126           FDC35        7.435
# 3336           FDC35        7.435
# 5769           FDC35        7.435
# ...
# 5295           NCR18          NaN
# 1738           NCR18       15.850
# 1795           NCR18       15.850
# 241            NCR18       15.850
# 7710           NCR18       15.850
# 1161           NCR29        7.565
# 3013           NCR29        7.565
# 763            NCR29        7.565
# 4375           NCR29          NaN
# 2977           NCR30       20.600
# 4957           NCR30          NaN
# 8114           NCR30       20.600
# 1230           NCR30       20.600
# 909            NCR30       20.600
# 5823           NCR30       20.600
# 240            NCR38       17.250
# 3531           NCR38       17.250
# 1206           NCR38       17.250
# 7368           NCR38          NaN
# 646            NCR38       17.250
# 8002           NCR38       17.250
# 6577           NCR41       17.850
# 7330           NCR41       17.850
# 548            NCR41       17.850
# 2441           NCR41       17.850
# 1290           NCR41          NaN
# 3024           NCR41       17.850
# 3373           NCR42        9.105
# 3586           NCR42        9.105
# 6950           NCR42        9.105
# 7878           NCR50       20.200
# 2941           NCR50       20.200
# 3125           NCR50       20.200
# 3234           NCR50          NaN
# 3017           NCR53          NaN
# 3497           NCR53       12.150
# 1508           NCR53       12.150
# 3238           NCR53       12.150
# 132            NCR53          NaN
# 4591           NCR53       12.150
# 2116           NCR53       12.150
# 1809           NCR54       16.350
# 265            NCR54       16.350
# 3477           NCR54       16.350
# 7750           NCR54          NaN
# 4302           NCR54       16.350
# 4711           NCS05       11.500
# 2848           NCS05       11.500
# 4063           NCS05          NaN
# 6718           NCS05       11.500
# 1654           NCS06        7.935
# 7776           NCS06        7.935
# 6484           NCS06          NaN
# 5091           NCS06        7.935
# 8410           NCS06        7.935
# 5117           NCS06        7.935
# 2153           NCS06          NaN
# 31             NCS17       18.600
# 7196           NCS17       18.600
# 7487           NCS17          NaN
# 1213           NCS17       18.600
# 8475           NCS17       18.600
# 6161           NCS18       12.650
# 6762           NCS18       12.650
# 2701           NCS18       12.650
# 4928           NCS18       12.650
# 5233           NCS18       12.650
# 5558           NCS29        9.000
# 4715           NCS29          NaN
# 7556           NCS29        9.000
# 5058           NCS29          NaN
# 4877           NCS29        9.000
# 5254           NCS29        9.000
# 5381           NCS30        5.945
# 8057           NCS30        5.945
# 4122           NCS30        5.945
# 6464           NCS30        5.945
# 5656           NCS30        5.945
# 6162           NCS30        5.945
# 3599           NCS30        5.945
# 7038           NCS38          NaN
# 2250           NCS38        8.600
# 4682           NCS38        8.600
# 2042           NCS38        8.600
# 8472           NCS41          NaN
# 1517           NCS41       12.850
# 8119           NCS42        8.600
# 7890           NCS42        8.600
# 1527           NCS42        8.600
# 7963           NCS42        8.600
# 4931           NCS53       14.500
# 2649           NCS53       14.500
# 5281           NCS53          NaN
# 3038           NCS53       14.500
# 6514           NCS53       14.500
# 3452           NCS53       14.500
# 5465           NCS53          NaN
# 8026           NCS53       14.500
# 5351           NCS54          NaN
# 939            NCS54       13.600
# 466            NCS54       13.600
# 1022           NCS54       13.600
# 7175           NCS54       13.600
# 8264           NCS54       13.600
# 6342           NCS54       13.600
# 8214           NCT05       10.895
# 8409           NCT05       10.895
# 1257           NCT05       10.895
# 7348           NCT05       10.895
# 6210           NCT06       17.100
# 5853           NCT06          NaN
# 5936           NCT06       17.100
# 1536           NCT06       17.100
# 2517           NCT06       17.100
# 2019           NCT17          NaN
# 6118           NCT17       10.800
# 6560           NCT17       10.800
# 7132           NCT17       10.800
# 5830           NCT17       10.800
# 2451           NCT18       14.600
# 703            NCT18       14.600
# 7071           NCT18       14.600
# 8023           NCT18          NaN
# 6533           NCT29       12.600
# 5766           NCT29          NaN
# 1557           NCT29       12.600
# 1524           NCT29          NaN
# 3398           NCT30          NaN
# 5243           NCT30        9.100
# 3329           NCT30        9.100
# 8293           NCT30        9.100
# 5948           NCT30        9.100
# 4293           NCT30        9.100
# 490            NCT41          NaN
# 4128           NCT41       15.700
# 5662           NCT41       15.700
# 6446           NCT41       15.700
# 5508           NCT41       15.700
# 4629           NCT42        5.880
# 4866           NCT42        5.880
# 6539           NCT42          NaN
# 4164           NCT42        5.880
# 2531           NCT42        5.880
# 7327           NCT42        5.880
# 7387           NCT53          NaN
# 8471           NCT53        5.400
# 4734           NCT53          NaN
# 476            NCT54        8.695
# 5755           NCT54        8.695
# 6213           NCT54        8.695
# 289            NCT54        8.695
# 2069           NCT54        8.695
# 8417           NCU05       11.800
# 239            NCU05          NaN
# 1595           NCU05       11.800
# 177            NCU05       11.800
# 2142           NCU05       11.800
# 4550           NCU05       11.800
# 6754           NCU06          NaN
# 5343           NCU06       17.600
# 3842           NCU06       17.600
# 7939           NCU17        5.320
# 4838           NCU17        5.320
# 4354           NCU17          NaN
# 697            NCU17        5.320
# 6401           NCU17        5.320
# 8122           NCU17        5.320
# 2551           NCU17        5.320
# 7157           NCU18       15.100
# 7784           NCU18       15.100
# 6774           NCU18          NaN
# 7335           NCU18       15.100
# 6621           NCU18       15.100
# 2553           NCU18       15.100
# 5635           NCU29          NaN
# 7333           NCU29          NaN
# 4923           NCU29        7.685
# 4977           NCU30        5.110
# 6823           NCU30        5.110
# 4911           NCU30        5.110
# 5929           NCU30        5.110
# 4438           NCU30        5.110
# 4282           NCU41       18.850
# 589            NCU41       18.850
# 424            NCU41       18.850
# 242            NCU41       18.850
# 2127           NCU42        9.000
# 5110           NCU42        9.000
# 4501           NCU42        9.000
# 4515           NCU42          NaN
# 8147           NCU42        9.000
# 7847           NCU42        9.000
# 8068           NCU53        5.485
# 6235           NCU53        5.485
# 6094           NCU53        5.485
# 8388           NCU53        5.485
# 1650           NCU54        8.880
# 1867           NCU54        8.880
# 3536           NCU54        8.880
# 6191           NCU54        8.880
# 2823           NCU54        8.880
# 7225           NCU54        8.880
# 707            NCV05       10.100
# 4423           NCV05       10.100
# 6709           NCV05          NaN
# 904            NCV05       10.100
# 6425           NCV05       10.100
# 2478           NCV06       11.300
# 710            NCV06       11.300
# 3685           NCV06       11.300
# 8337           NCV06          NaN
# 4312           NCV06       11.300
# 6408           NCV06       11.300
# 2752           NCV06       11.300
# 1987           NCV06          NaN
# 448            NCV17       18.850
# 8216           NCV17       18.850
# 1801           NCV17       18.850
# 6850           NCV17       18.850
# 7136           NCV18        6.775
# 5304           NCV18        6.775
# 5628           NCV29       11.800
# 7921           NCV29          NaN
# 4485           NCV29       11.800
# 5714           NCV29       11.800
# 5459           NCV29       11.800
# 3502           NCV30       20.200
# 8307           NCV30       20.200
# 6767           NCV30          NaN
# 1574           NCV30       20.200
# 861            NCV30       20.200
# 2422           NCV41       14.350
# 1387           NCV41       14.350
# 8258           NCV41       14.350
# 2287           NCV41       14.350
# 2873           NCV41       14.350
# 2742           NCV41          NaN
# 3847           NCV41       14.350
# 5316           NCV41       14.350
# 4090           NCV42        6.260
# 463            NCV42        6.260
# 579            NCV42        6.260
# 2935           NCV53        8.270
# 2830           NCV53        8.270
# 3542           NCV53        8.270
# 7118           NCV53        8.270
# 5534           NCV53        8.270
# 6243           NCV54       11.100
# 4737           NCV54       11.100
# 2759           NCV54       11.100
# 1172           NCV54       11.100
# 695            NCV54          NaN
# 1355           NCV54       11.100
# 5729           NCV54          NaN
# 7298           NCW05       20.250
# 7857           NCW05       20.250
# 3954           NCW06       16.200
# 7279           NCW06       16.200
# 4171           NCW06       16.200
# 8056           NCW06       16.200
# 6469           NCW06       16.200
# 2020           NCW17       18.000
# 328            NCW17          NaN
# 6940           NCW17       18.000
# 6182           NCW17       18.000
# 1915           NCW18       15.100
# 4269           NCW18       15.100
# 5866           NCW18       15.100
# 6398           NCW18          NaN
# 5871           NCW29          NaN
# 187            NCW29       14.000
# 5805           NCW29       14.000
# 7097           NCW29       14.000
# 1256           NCW29          NaN
# 3964           NCW29       14.000
# 7635           NCW30        5.210
# 7039           NCW30        5.210
# 3644           NCW41       18.000
# 3943           NCW41       18.000
# 4746           NCW41          NaN
# 6265           NCW41       18.000
# 5497           NCW41       18.000
# 4793           NCW42          NaN
# 1444           NCW42       18.200
# 4803           NCW42          NaN
# 1086           NCW42       18.200
# 5454           NCW42       18.200
# 3351           NCW53       18.350
# 3763           NCW53       18.350
# 7183           NCW53       18.350
# 7447           NCW53       18.350
# 3774           NCW53       18.350
# 371            NCW53          NaN
# 3922           NCW53          NaN
# 7240           NCW54        7.500
# 1773           NCW54        7.500
# 6215           NCW54        7.500
# 4134           NCW54        7.500
# 4277           NCW54        7.500
# 4334           NCX05       15.200
# 6485           NCX05       15.200
# 8378           NCX05       15.200
# 4783           NCX05       15.200
# 5156           NCX05       15.200
# 3910           NCX05          NaN
# 1462           NCX05          NaN
# 7226           NCX05       15.200
# 4172           NCX06       17.600
# 5847           NCX06          NaN
# 2372           NCX06       17.600
# 2689           NCX06       17.600
# 194            NCX06          NaN
# 7158           NCX17       21.250
# 7042           NCX17       21.250
# 5717           NCX17       21.250
# 2226           NCX18       14.150
# 2960           NCX18       14.150
# 5052           NCX18       14.150
# 1395           NCX18       14.150
# 7086           NCX18       14.150
# 2931           NCX18          NaN
# 2587           NCX18       14.150
# 1028           NCX29          NaN
# 6367           NCX29       10.000
# 6731           NCX29       10.000
# 35             NCX29       10.000
# 507            NCX29       10.000
# 1994           NCX29       10.000
# 7985           NCX29       10.000
# 1211           NCX29       10.000
# 8319           NCX30       16.700
# 1680           NCX30          NaN
# 4948           NCX30       16.700
# 2282           NCX30       16.700
# 5892           NCX30       16.700
# 5919           NCX30          NaN
# 403            NCX41       19.000
# 4879           NCX41       19.000
# 8353           NCX41          NaN
# 1120           NCX41       19.000
# 6827           NCX41       19.000
# 8061           NCX41       19.000
# 516            NCX42        6.360
# 7711           NCX42        6.360
# 6260           NCX42        6.360
# 850            NCX42        6.360
# 1525           NCX42        6.360
# 5671           NCX42          NaN
# 230            NCX42          NaN
# 3258           NCX53       20.100
# 7346           NCX53       20.100
# 6384           NCX54          NaN
# 56             NCX54        9.195
# 7661           NCX54        9.195
# 3015           NCX54        9.195
# 3998           NCX54        9.195
# 7061           NCX54        9.195
# 141            NCX54        9.195
# 990            NCY05       13.500
# 1713           NCY05          NaN
# 1070           NCY05       13.500
# 5591           NCY05       13.500
# 5168           NCY05       13.500
# 8077           NCY06       15.250
# 5491           NCY06          NaN
# 2152           NCY06       15.250
# 3846           NCY06       15.250
# 8338           NCY06       15.250
# 4113           NCY17       18.200
# 3579           NCY17       18.200
# 5079           NCY17       18.200
# 6610           NCY17       18.200
# 2690           NCY17       18.200
# 4233           NCY18          NaN
# 1756           NCY18        7.285
# 7869           NCY18        7.285
# 736            NCY18        7.285
# 2079           NCY18        7.285
# 2976           NCY18        7.285
# 342            NCY18        7.285
# 6050           NCY18        7.285
# 1639           NCY18        7.285
# 8141           NCY29       13.650
# 8120           NCY29          NaN
# 1287           NCY29       13.650
# 7699           NCY29       13.650
# 3431           NCY29       13.650
# 2341           NCY29       13.650
# 7453           NCY29       13.650
# 2021           NCY29          NaN
# 3281           NCY30       20.250
# 6016           NCY30       20.250
# 2534           NCY30       20.250
# 343            NCY30       20.250
# 6933           NCY41          NaN
# 1065           NCY41       16.750
# 871            NCY41       16.750
# 4255           NCY41       16.750
# 1518           NCY41       16.750
# 3500           NCY41       16.750
# 1321           NCY41       16.750
# 7573           NCY42        6.380
# 8052           NCY42        6.380
# 3612           NCY42        6.380
# 4831           NCY42        6.380
# 5985           NCY53       20.000
# 6126           NCY53       20.000
# 7013           NCY53          NaN
# 3688           NCY53       20.000
# 7527           NCY53       20.000
# 5924           NCY54        8.430
# 3662           NCY54        8.430
# 1874           NCY54        8.430
# 7002           NCY54          NaN
# 3244           NCZ05        8.485
# 7873           NCZ05          NaN
# 1208           NCZ05        8.485
# 5357           NCZ06       19.600
# 1331           NCZ06       19.600
# 698            NCZ06          NaN
# 3613           NCZ06          NaN
# 4625           NCZ06       19.600
# 1900           NCZ06       19.600
# 790            NCZ06       19.600
# 1397           NCZ17          NaN
# 7832           NCZ17       12.150
# 6716           NCZ17       12.150
# 2872           NCZ17       12.150
# 7265           NCZ17       12.150
# 4280           NCZ17       12.150
# 281            NCZ18        7.825
# 3750           NCZ18          NaN
# 7839           NCZ18        7.825
# 74             NCZ18        7.825
# 1087           NCZ18        7.825
# 7905           NCZ18        7.825
# 3863           NCZ18        7.825
# 7108           NCZ29       15.000
# 8054           NCZ29       15.000
# 3468           NCZ29       15.000
# 4528           NCZ29       15.000
# 3220           NCZ30        6.590
# 1224           NCZ30        6.590
# 4523           NCZ30          NaN
# 3739           NCZ30        6.590
# 2428           NCZ30        6.590
# 7068           NCZ30        6.590
# 4418           NCZ30        6.590
# 6965           NCZ41       19.850
# 5119           NCZ41       19.850
# 6744           NCZ41       19.850
# 5271           NCZ41       19.850
# 922            NCZ41       19.850
# 411            NCZ42       10.500
# 1115           NCZ42       10.500
# 6488           NCZ42       10.500
# 6056           NCZ42       10.500
# 3775           NCZ42       10.500
# 6879           NCZ53        9.600
# 4924           NCZ53        9.600
# 2084           NCZ53          NaN
# 1267           NCZ53        9.600
# 3959           NCZ53        9.600
# 2839           NCZ54       14.650
# 1969           NCZ54       14.650
# 7926           NCZ54       14.650
# 214            NCZ54       14.650
# 1896           NCZ54          NaN
# 7166           NCZ54          NaN
# 7738           NCZ54       14.650

# %% [markdown]
# It can be observed that, items with the same identifier have similar weights.

# %%
#creating a dictionary with item identifier as key and item_weight as value
item_weight_dict={}
for item in set(data['Item_Identifier']):
    item_weight_dict[item]=data['Item_Weight'][data['Item_Identifier']==item].mean()

# %% [markdown]
# The missing weights are filled from the dictionary.

# %%
for ind in data[data['Item_Weight'].isnull()==True].index:
    data['Item_Weight'][ind]=item_weight_dict[data['Item_Identifier'][ind]]

# %%
data[data['Item_Weight'].isnull()==True]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 927            FDN52          NaN          Regular         0.130933
# 1922           FDK57          NaN          Low Fat         0.079904
# 4187           FDE52          NaN          Regular         0.029742
# 5022           FDQ60          NaN          Regular         0.191501
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 927   Frozen Foods   86.9198            OUT027                       1985
# 1922   Snack Foods  120.0440            OUT027                       1985
# 4187         Dairy   88.9514            OUT027                       1985
# 5022  Baking Goods  121.2098            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 927       Medium               Tier 3  Supermarket Type3          1569.9564
# 1922      Medium               Tier 3  Supermarket Type3          4434.2280
# 4187      Medium               Tier 3  Supermarket Type3          3453.5046
# 5022       Small               Tier 1      Grocery Store           120.5098

# %% [markdown]
# The above items have unique identifiers. Their weight will be almost equal to items of similar type, fat_content and MRP.

# %%
data['Item_Weight'][927]=data['Item_Weight'][(data['Item_Type']=='Frozen Foods') & (data['Item_Fat_Content']=='Regular') & (data['Item_MRP']>85)& (data['Item_MRP']<90)].mean()
data['Item_Weight'][1922]=data['Item_Weight'][(data['Item_Type']=='Snack Foods') & (data['Item_Fat_Content']=='Low Fat') & (data['Item_MRP']>118)& (data['Item_MRP']<122)].mean()
data['Item_Weight'][4187]=data['Item_Weight'][(data['Item_Type']=='Dairy') & (data['Item_Fat_Content']=='Regular') & (data['Item_MRP']>85)& (data['Item_MRP']<90)].mean()
data['Item_Weight'][5022]=data['Item_Weight'][(data['Item_Type']=='Baking Goods') & (data['Item_Fat_Content']=='Regular') & (data['Item_MRP']>119)& (data['Item_MRP']<123)].mean()

# %% [markdown]
# ### 2.1.2 Handling null values in 'Outlet_Size'

# %%
data['Outlet_Identifier'][data['Outlet_Size'].isnull()==True].value_counts()
# Out:
# OUT045    929
# OUT017    926
# OUT010    555
# Name: Outlet_Identifier, dtype: int64

# %% [markdown]
# The missing data are from three outlets.

# %% [markdown]
# They can be filled with the mode value.

# %%
data['Outlet_Size']=data['Outlet_Size'].fillna(data['Outlet_Size'].mode()[0])

# %%
data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# ## 2.2 Handling outliers

# %%
#selecting the integer datatype features
data_int = data.select_dtypes(include=['int64','float64'])
data_int.boxplot(figsize = (16,6))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# There are outliers in the feature 'Item_Visibility'.

# %%
#defining a function to handle outliers
def outlier_check(col):
    #calculating percentiles
    Q1=np.percentile(data[col],25,interpolation='midpoint')
    Q2=np.percentile(data[col],50,interpolation='midpoint')
    Q3=np.percentile(data[col],75,interpolation='midpoint')
    print('Q1 = ',round(Q1,3),'\nQ2 = ',round(Q2,3),'\nQ3 = ',round(Q3,3))

    #calculating inter quartile range
    IQR=Q3-Q1
    print('IQR = ',round(IQR,3))

    #calculating the upper and lower limit of outliers
    low_lim=Q1-(1.5*IQR)
    up_lim=Q3+(1.5*IQR)
    print('Upper limit = ',round(up_lim,3),'\nLower limit = ',round(low_lim,3))

    #creating a list of outliers
    outlier=[]
    for x in data[col]:
        if (x>up_lim or x<low_lim):
            outlier.append(round(x,3))
    print('Outliers are :',outlier)

# %%
outlier_check('Item_Visibility')
# Out:
# Q1 =  0.027
# Q2 =  0.054
# Q3 =  0.095
# IQR =  0.068
# Upper limit =  0.196
# Lower limit =  -0.074
# Outliers are : [0.255, 0.293, 0.279, 0.292, 0.205, 0.264, 0.229, 0.298, 0.233, 0.21, 0.22, 0.328, 0.205, 0.247, 0.214, 0.227, 0.223, 0.267, 0.256, 0.244, 0.255, 0.225, 0.224, 0.246, 0.236, 0.27, 0.205, 0.321, 0.248, 0.274, 0.208, 0.196, 0.235, 0.241, 0.196, 0.304, 0.232, 0.216, 0.198, 0.213, 0.238, 0.222, 0.295, 0.284, 0.235, 0.309, 0.277, 0.213, 0.254, 0.204, 0.237, 0.206, 0.213, 0.228, 0.232, 0.305, 0.292, 0.243, 0.298, 0.326, 0.266, 0.209, 0.256, 0.247, 0.273, 0.208, 0.2, 0.225, 0.21, 0.308, 0.245, 0.268, 0.218, 0.211, 0.233, 0.293, 0.29, 0.253, 0.22, 0.28, 0.216, 0.198, 0.202, 0.305, 0.215, 0.295, 0.198, 0.212, 0.287, 0.216, 0.212, 0.302, 0.286, 0.2, 0.245, 0.251, 0.29, 0.226, 0.236, 0.247, 0.238, 0.209, 0.224, 0.239, 0.209, 0.297, 0.305, 0.2, 0.208, 0.291, 0.24, 0.211, 0.256, 0.199, 0.216, 0.21, 0.205, 0.28, 0.197, 0.214, 0.205, 0.237, 0.222, 0.244, 0.286, 0.311, 0.226, 0.199, 0.282, 0.279, 0.235, 0.307, 0.211, 0.225, 0.251, 0.275, 0.299, 0.28, 0.297, 0.209, 0.266, 0.214, 0.227, 0.214]

# %% [markdown]
# As 'Item_Visibility' denotes the % of total display area of all products in a store allocated to the particular product, it can never go beyond 100%.

# %% [markdown]
# Hence, the outliers can be capped to the upper limit of outliers.

# %%
for ind in data.loc[(data['Item_Visibility']>0.196 )].index:
    data['Item_Visibility'][ind]=0.196

# %% [markdown]
# ## 2.3 Feature Engineering

# %% [markdown]
# As we can see, in the outlet establishment year category,the established years are given as they are.Since these are
# high values they can affect the model performance.In order to avoid this we can create a new attribute.The dataset is
# collected in 2013 and so we can find the duration of the year for establishing each outlet by negating each establishment year
# from 2013.

# %%
#creating a new feature to find the age of the outlet in '2013'
data['Outlet_Years']=2013-data['Outlet_Establishment_Year']
data['Outlet_Years'].describe()
# Out:
# count    8523.000000
# mean       15.168133
# std         8.371760
# min         4.000000
# 25%         9.000000
# 50%        14.000000
# 75%        26.000000
# max        28.000000
# Name: Outlet_Years, dtype: float64

# %%
data.drop('Outlet_Establishment_Year',axis=1,inplace=True)

# %%
data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
# The labels of  the feature 'Item_Fat_Content' can be grouped into low fat and regular (Combining repeared labels)
data['Item_Fat_Content'] = data['Item_Fat_Content'].replace({'LF':'Low Fat', 'reg':'Regular', 'low fat':'Low Fat'})
data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# Closely examining the item category we can define three categories like food,drink and nonconsumables

# %%
data['New_Item_Type'] = data['Item_Identifier'].apply(lambda x: x[:2]) # To get the first two letters from the feature
data['New_Item_Type'].value_counts()
# Out:
# FD    6125
# NC    1599
# DR     799
# Name: New_Item_Type, dtype: int64

# %%
# If a product is non-consumable there is no need to associate fat content to them
#So it can be changed to another category 'non edible'

data.loc[data['New_Item_Type']=='NC', 'Item_Fat_Content'] = 'Non-Edible'
data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       3918
# Regular       3006
# Non-Edible    1599
# Name: Item_Fat_Content, dtype: int64

# %%
data.drop('New_Item_Type',axis=1,inplace=True)

# %% [markdown]
# ## 2.4 Encoding

# %%
#descriptive statistics
data.describe(include=object)
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                3                     16
# top              FDW13          Low Fat  Fruits and Vegetables
# freq                10             3918                   1232
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               8523        8523                 8523               8523
# unique                10           3                    3                  4
# top               OUT027      Medium               Tier 3  Supermarket Type1
# freq                 935        5203                 3350               5577

# %% [markdown]
# ### 2.4.1 Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc_state=LabelEncoder()
for col in ['Item_Identifier','Item_Type','Outlet_Identifier','Outlet_Type','Item_Fat_Content']:
    lab_enc_state.fit(data[col])
    data[col]=lab_enc_state.transform(data[col])

# %% [markdown]
# ### 2.4.2 Encoding Outlet_Size

# %%
data['Outlet_Size'].value_counts()
# Out:
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
# mapping 'Outlet_Size' feature
data['Outlet_Size'] =data['Outlet_Size'].map({'Small':0, 'Medium':1, 'High':2})
data['Outlet_Size'].value_counts()
# Out:
# 1    5203
# 0    2388
# 2     932
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# ### 2.4.3 Encoding Outlet_Location_Type

# %%
data['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
# mapping 'Outlet_Location_Type' feature
data['Outlet_Location_Type'] =data['Outlet_Location_Type'].map({'Tier 1':1, 'Tier 2':2, 'Tier 3':3})
data['Outlet_Location_Type'].value_counts()
# Out:
# 3    3350
# 2    2785
# 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %% [markdown]
# ## 2.5 Feature Scaling

# %%
#dependent variable is stored in y
y=data['Item_Outlet_Sales']
#independent variable is stored in x
x=data.drop(['Item_Outlet_Sales'],axis=1) 
x.describe()
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# count      8523.000000  8523.000000       8523.000000      8523.000000
# mean        779.714889    12.875002          0.892995         0.065307
# std         449.222377     4.645352          0.895005         0.048842
# min           0.000000     4.555000          0.000000         0.000000
# 25%         395.500000     8.785000          0.000000         0.026989
# 50%         783.000000    12.650000          1.000000         0.053931
# 75%        1167.000000    16.850000          2.000000         0.094585
# max        1558.000000    21.350000          2.000000         0.196000
#
#          Item_Type     Item_MRP  Outlet_Identifier  Outlet_Size  \
# count  8523.000000  8523.000000        8523.000000  8523.000000
# mean      7.226681   140.992782           4.722281     0.829168
# std       4.209990    62.275067           2.837201     0.600327
# min       0.000000    31.290000           0.000000     0.000000
# 25%       4.000000    93.826500           2.000000     0.000000
# 50%       6.000000   143.012800           5.000000     1.000000
# 75%      10.000000   185.643700           7.000000     1.000000
# max      15.000000   266.888400           9.000000     2.000000
#
#        Outlet_Location_Type  Outlet_Type  Outlet_Years
# count           8523.000000  8523.000000   8523.000000
# mean               2.112871     1.201220     15.168133
# std                0.812757     0.796459      8.371760
# min                1.000000     0.000000      4.000000
# 25%                1.000000     1.000000      9.000000
# 50%                2.000000     1.000000     14.000000
# 75%                3.000000     1.000000     26.000000
# max                3.000000     3.000000     28.000000

# %%
#min max scaling
from sklearn import preprocessing
min_max=preprocessing.MinMaxScaler()
x=min_max.fit_transform(x)
x=pd.DataFrame(x)
x.describe()
# Out:
#                 0            1            2            3            4   \
# count  8523.000000  8523.000000  8523.000000  8523.000000  8523.000000
# mean      0.500459     0.495386     0.446498     0.333201     0.481779
# std       0.288333     0.276591     0.447503     0.249195     0.280666
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.253851     0.251861     0.000000     0.137701     0.266667
# 50%       0.502567     0.481989     0.500000     0.275158     0.400000
# 75%       0.749037     0.732063     1.000000     0.482578     0.666667
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 5            6            7            8            9   \
# count  8523.000000  8523.000000  8523.000000  8523.000000  8523.000000
# mean      0.465635     0.524698     0.414584     0.556436     0.400407
# std       0.264327     0.315245     0.300164     0.406379     0.265486
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.265437     0.222222     0.000000     0.000000     0.333333
# 50%       0.474209     0.555556     0.500000     0.500000     0.333333
# 75%       0.655156     0.777778     0.500000     1.000000     0.333333
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 10
# count  8523.000000
# mean      0.465339
# std       0.348823
# min       0.000000
# 25%       0.208333
# 50%       0.416667
# 75%       0.916667
# max       1.000000

# %% [markdown]
# # 3. Modelling

# %%
#splitting the dataset for training the model and validating
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %% [markdown]
# ## 3.1 Linear Regression Model

# %%
#Linear model
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
predictions=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
MSE_lin_reg=mean_squared_error(predictions,y_test)
print('Mean of squared errors of the linear regression model is ',round(MSE_lin_reg,3))
# Out:
# Mean of squared errors of the linear regression model is  1292111.648

# %% [markdown]
# ## 3.2 Polynomial Regression Model

# %%
#polynomial regression model with degree 2
from sklearn.preprocessing import PolynomialFeatures  
poly_regs= PolynomialFeatures(degree= 2)

#converting feature matrix into polynomial feature matrix
x_poly= poly_regs.fit_transform(x_train)  
poly =linear_model.LinearRegression()  
model=poly.fit(x_train, y_train) 
predictions=model.predict(x_test)

# %%
MSE_poly_reg2=mean_squared_error(predictions,y_test)
print('Mean of squared errors of the Polynomial regression model is ',round(MSE_poly_reg2,3))
# Out:
# Mean of squared errors of the Polynomial regression model is  1292111.648

# %%
#polynomial regression model with degree 5
poly_regs= PolynomialFeatures(degree= 5)  
x_poly= poly_regs.fit_transform(x_train)  
poly =linear_model.LinearRegression()  
model=poly.fit(x_train, y_train) 
predictions=model.predict(x_test)

# %%
MSE_poly_reg5=mean_squared_error(predictions,y_test)
print('Mean of squared errors of the linear Polynomial model is ',round(MSE_poly_reg5,3))
# Out:
# Mean of squared errors of the linear Polynomial model is  1292111.648

# %% [markdown]
# ## 3.3 Ridge Regression Model

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.016,normalize=True)
model=ridge_reg.fit(x_train, y_train)
predictions = model.predict(x_test)

# %%
MSE_ridg_reg=mean_squared_error(predictions,y_test)
print('Mean of squared errors of the Ridge regression model is ',round(MSE_ridg_reg,3))
# Out:
# Mean of squared errors of the Ridge regression model is  1293064.666

# %% [markdown]
# ## 3.4 LASSO Regression Model

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
model=lasso.fit(x_train, y_train)
predictions = model.predict(x_test)

# %%
MSE_lasso=mean_squared_error(predictions,y_test)
print('Mean of squared errors of the LASSO regression model is ',round(MSE_lasso,3))
# Out:
# Mean of squared errors of the LASSO regression model is  1291363.089

# %% [markdown]
# ## 3.5 Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt_model=dt.fit(x_train,y_train)
dt_pred=dt_model.predict(x_test)

# %%
MSE_Deci=mean_squared_error(dt_pred,y_test)
print('Mean of squared errors of the LASSO regression model is ',round(MSE_Deci,3))
# Out:
# Mean of squared errors of the LASSO regression model is  2357649.509

# %% [markdown]
# ## 3.6 Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf_model=rf.fit(x_train,y_train)
rf_pred=rf_model.predict(x_test)

# %%
MSE_rf=mean_squared_error(rf_pred,y_test)
print('Mean of squared errors of the LASSO regression model is ',round(MSE_rf,3))
# Out:
# Mean of squared errors of the LASSO regression model is  1189443.459

# %% [markdown]
# # Summary

# %%
print('MSE values for different models:\n')
print('Linear Regression Model : ',round(MSE_lin_reg))
print('Polynomial Regression Model(Degree = 2) : ',round(MSE_poly_reg2))
print('Polynomial Regression Model(Degree = 5) : ',round(MSE_poly_reg5))
print('Ridge Regression Model : ',round(MSE_ridg_reg))
print('Lasso Regression Model : ',round(MSE_lasso))
print('Decision Tree : ',round(MSE_Deci))
print('Random Forest : ',round(MSE_rf))
# Out:
# MSE values for different models:
#
# Linear Regression Model :  1292112
# Polynomial Regression Model(Degree = 2) :  1292112
# Polynomial Regression Model(Degree = 5) :  1292112
# Ridge Regression Model :  1293065
# Lasso Regression Model :  1291363
# Decision Tree :  2357650
# Random Forest :  1189443

# %% [markdown]
# Random Forest is found to give the best results. Hence, fine tuning the model.

# %% [markdown]
# # 4. Hyperparameter Finetuning

# %%
#number of trees in the forest
n_estimators=[100,150,200]
#maximum depth of the tree
max_depth=[4,5,6,7]
#minimum number of samples required to split an internal node
min_samples_split=[2,3,4]
#number of features to consider when looking for the best split
max_features=['sqrt','log2', None]

# %%
# Create the param grid
param_grid = {
    'n_estimators':n_estimators,
    'max_depth':max_depth,
    'min_samples_split':min_samples_split,
    'max_features':max_features
}

# %%
from sklearn.model_selection import GridSearchCV
rf_Grid = GridSearchCV(estimator = rf, param_grid = param_grid, verbose=2,n_jobs=4,cv=3)

# %%
rf_Grid.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=4,
#              param_grid={'max_depth': [4, 5, 6, 7],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [100, 150, 200]},
#              verbose=2)

# %%
rf_Grid.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': None,
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
rf=RandomForestRegressor(max_depth=5,max_features=None,min_samples_split=3,n_estimators=200)
rf_model=rf.fit(x_train,y_train)
rf_pred=rf_model.predict(x_test)
MSE_rf=mean_squared_error(rf_pred,y_test)
print('Mean of squared errors of the LASSO regression model is ',round(MSE_rf,3))
# Out:
# Mean of squared errors of the LASSO regression model is  1036217.446

# %% [markdown]
# The MSE value has reduced after fine tuning.

# %% [markdown]
# # 5. Preprocessing the test data

# %%
#storing the test dataset to a dataframe named 'test'
test=pd.read_csv('test_AbJTz2l.csv')

# %%
#displaying the first few rows
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %% [markdown]
# ## 5.1 Handling null values

# %%
test.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
#filling the 'item-weight' from the item-weight dictionary
for ind in test[test['Item_Weight'].isnull()==True].index:
    test['Item_Weight'][ind]=item_weight_dict[test['Item_Identifier'][ind]]

# %%
test[test['Item_Weight'].isnull()==True]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1724           FDQ60          NaN          Regular         0.108845
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 1724  Baking Goods  118.5098            OUT027                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type
# 1724      Medium               Tier 3  Supermarket Type3

# %%
#filling with items having similar type and price
test['Item_Weight'][1724]=test['Item_Weight'][(test['Item_Type']=='Baking Goods') & (test['Item_Fat_Content']=='Regular') & (test['Item_MRP']>115)& (test['Item_MRP']<120)].mean()

# %%
test['Outlet_Identifier'][test['Outlet_Size'].isnull()].value_counts()
# Out:
# OUT045    619
# OUT017    617
# OUT010    370
# Name: Outlet_Identifier, dtype: int64

# %%
#These outlets had missing size as in the train, hence filling with the mode
test['Outlet_Size']=test['Outlet_Size'].fillna('Medium')

# %% [markdown]
# ## 5.2 Feature Engineering

# %%
#creating a new feature to find the age of the outlet in '2013'
test['Outlet_Years']=2013-test['Outlet_Establishment_Year']

# %%
test.drop('Outlet_Establishment_Year',axis=1,inplace=True)

# %%
test['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: Item_Fat_Content, dtype: int64

# %%
# The labels of  the feature 'Item_Fat_Content' can be grouped into low fat and regular (Combining repeared labels)
test['Item_Fat_Content'] = test['Item_Fat_Content'].replace({'LF':'Low Fat', 'reg':'Regular', 'low fat':'Low Fat'})
test['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    3668
# Regular    2013
# Name: Item_Fat_Content, dtype: int64

# %%
test['New_Item_Type'] = test['Item_Identifier'].apply(lambda x: x[:2]) # To get the first two letters from the feature

# If a product is non-consumable there is no need to associate fat content to them
#So it can be changed to another category 'non edible'

test.loc[test['New_Item_Type']=='NC', 'Item_Fat_Content'] = 'Non-Edible'
test['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       2581
# Regular       2013
# Non-Edible    1087
# Name: Item_Fat_Content, dtype: int64

# %%
test.drop('New_Item_Type',axis=1,inplace=True)

# %%
#saving the required columns before encoding
output=test[['Item_Identifier','Outlet_Identifier']]

# %% [markdown]
# ## 5.3 Encoding

# %%
# mapping 'Outlet_Size' feature
test['Outlet_Size'] =test['Outlet_Size'].map({'Small':0, 'Medium':1, 'High':2})
# mapping 'Outlet_Location_Type' feature
test['Outlet_Location_Type'] =test['Outlet_Location_Type'].map({'Tier 1':1, 'Tier 2':2, 'Tier 3':3})

lab_enc_state=LabelEncoder()
for col in ['Item_Identifier','Item_Type','Outlet_Identifier','Outlet_Type','Item_Fat_Content']:
    lab_enc_state.fit(test[col])
    test[col]=lab_enc_state.transform(test[col])

# %% [markdown]
# ## 5.4 Feature Scaling

# %%
min_max=preprocessing.MinMaxScaler()
scaled_test=min_max.fit_transform(test)
scaled_test=pd.DataFrame(scaled_test)
scaled_test.describe()
# Out:
#                 0            1            2            3            4   \
# count  5681.000000  5681.000000  5681.000000  5681.000000  5681.000000
# mean      0.501548     0.483360     0.450009     0.202955     0.482227
# std       0.288927     0.277357     0.446879     0.158364     0.281270
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.247730     0.241739     0.000000     0.083572     0.266667
# 50%       0.500000     0.464126     0.500000     0.167330     0.400000
# 75%       0.752270     0.723132     1.000000     0.288788     0.666667
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 5            6            7            8            9   \
# count  5681.000000  5681.000000  5681.000000  5681.000000  5681.000000
# mean      0.464766     0.524751     0.414540     0.556416     0.400458
# std       0.263468     0.315245     0.300164     0.406412     0.265580
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.266080     0.222222     0.000000     0.000000     0.333333
# 50%       0.466437     0.555556     0.500000     0.500000     0.333333
# 75%       0.656597     0.777778     0.500000     1.000000     0.333333
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 10
# count  5681.000000
# mean      0.465462
# std       0.348844
# min       0.000000
# 25%       0.208333
# 50%       0.416667
# 75%       0.916667
# max       1.000000

# %% [markdown]
# # 6. Predicting the 'Outlet_Sales' using the Random Forest Model

# %%
rf=RandomForestRegressor(max_depth=5,max_features=None,min_samples_split=3,n_estimators=200)
rf_pred_test=rf_model.predict(scaled_test)
rf_pred_test
# Out:
# array([1595.83652882, 1437.22313361,  555.56880627, ..., 1958.8271875 ,
#        3527.11555682, 1246.48670462])

# %% [markdown]
# # 7. Saving the predicted values to a new dataframe 'Output'

# %%
output['Item_Outlet_Sales']=rf_pred_test
output.head()
# Out:
#   Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0           FDW58            OUT049        1595.836529
# 1           FDW14            OUT017        1437.223134
# 2           NCN55            OUT010         555.568806
# 3           FDQ58            OUT017        2470.992894
# 4           FDY38            OUT027        6268.567357

# %%
#saving as csv file
output.to_csv('output.csv',index=False)
